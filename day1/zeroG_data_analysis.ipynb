# %%
import numpy as np
from matplotlib import pyplot as plt

# Magic function to make matplotlib inline; other style specs must come AFTER
# %matplotlib inline
# %matplotlib notebook

# %%
file = open("3rd_5.txt", "r") 
lin_accel_x = []
lin_accel_y = []
lin_accel_z = []
lin_accel_mag = []
indexes = []

for i,line in enumerate(file):
    dat = line.split(' ')
    if (dat[0] == "N1"):
        accel = dat[5].split(',')
        a_x = float(accel[0])
        a_y = float(accel[1])
        a_z = float(accel[2])
        indexes.append(i)
        lin_accel_x.append(a_x)
        lin_accel_y.append(a_y)
        lin_accel_z.append(a_z)
        lin_accel_mag.append(np.sqrt(a_x**2+a_y**2+a_z**2))

lin_accel_x = np.array(lin_accel_x)
lin_accel_y = np.array(lin_accel_y)
lin_accel_z = np.array(lin_accel_z)
lin_accel_mag = np.array(lin_accel_mag)
indexes = np.array(indexes)

print(lin_accel_x[:10])
# Out:
# [ 1.38  1.38  1.38  1.38  1.38  1.38  1.38  1.38  1.38  1.38]

# %%
plt.close('all')
fig, ax1 = plt.subplots()
ax1.plot(lin_accel_x[:50000])
ax1.set_ylabel("Linear Acceleration in Z (m/s/s)")
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
file = open("3rd_5.txt", "r") 
euler_yaw = []
euler_pitch = []
euler_roll = []
lin_accel_mag = []
indexes = []

for i,line in enumerate(file):
    dat = line.split(' ')
    if (dat[0] == "N1"):
        euler = dat[5].split(',')
        e_y = float(euler[0])
        e_p = float(euler[1])
        e_r = float(euler[2])
        indexes.append(i)
        if (e_y > 180):
            e_y -= 360
        if (e_r > 90):
            e_r -= 180
        elif (e_r < -90):
            e_r += 180
        euler_yaw.append(e_y)
        euler_pitch.append(e_p)
        euler_roll.append(e_r)

euler_yaw = np.array(euler_yaw)
euler_pitch = np.array(euler_pitch)
euler_roll = np.array(euler_roll)
# lin_accel_mag = np.array(lin_accel_mag)
indexes = np.array(indexes)

print(euler_yaw[:10])
# Out:
# [ 1.38  1.38  1.38  1.38  1.38  1.38  1.38  1.38  1.38  1.38]

# %%
plt.close('all')
fig, ax1 = plt.subplots()
ax1.plot(euler_yaw[:50000])
plt.show()
# Out:
# <img src="data:image/png;base64,...">
